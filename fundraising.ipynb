# %%
import pandas as pd
import ast
from datetime import datetime

dtype_dict = {
    'deal_id': str,
    'pb_id': str,
    'name': str,
    'deal_number': int,
    'year_founded': 'Int64',
    'deal_size': float,
    'post_valuation': float,
    'total_vc_funding': float,
    'total_invested_equity': float,
    'deal_type': str,
    'deal_type2': str,
    'vc_round': str,
    'lead_investor': str,
    'company_website': str,
    'hq_location': str,
    'description': str,
    'primary_industry_code': str,
    'primary_industry_group': str,
    'primary_industry_sector': str
}

def parse_list(x):
    if pd.isna(x) or x == '[]':
        return []
    try:
        return ast.literal_eval(x)
    except:
        return []

def parse_date(x):
    if pd.isna(x):
        return None
    try:
        return datetime.strptime(x, '%Y-%m-%d')
    except:
        return None

def read_data(path: str):

    df = pd.read_csv(path, 
                     sep='\t',
                     dtype=dtype_dict,
                     converters={
                         'deal_date': parse_date,
                         'investors': parse_list,
                         'investor_ids': parse_list,
                         'first_time_investors': parse_list,
                         'keywords': parse_list,
                         'verticals': parse_list
                     },
                     na_values=['', 'nan', 'NULL'])
    
    df['post_valuation_status'] = df['post_valuation_status'].astype('category')
    return df

def convert_vc_round(round_str):
    if pd.isna(round_str) or not round_str:
        return None
    
    mapping = {
        '1st': 1,
        '2nd': 2,
        '3rd': 3,
        '4th': 4,
        '5th': 5,
        '6th': 6,
        '7th': 7,
        '8th': 8,
        '9th': 9,
        '10th': 10,
        'Angel': 0,
    }
    
    round_lower = round_str.lower()
    for key in mapping:
        if key in round_lower:
            return mapping[key]
    return None

# %%
df = read_data(path="./fundraising.tsv")

# %%
def get_early_stage_deals(df: pd.DataFrame, threshold_millions: int) -> pd.DataFrame:
    # Sort by date and calculate cumulative funding
    df_sorted = df.sort_values(['pb_id', 'deal_number'])
    df_sorted['cumulative_funding'] = df_sorted.groupby('pb_id')['deal_size'].cumsum()
    
    # Get first deal that takes the firm over the threshold
    result = (df_sorted[df_sorted['cumulative_funding'] >= threshold_millions]
              .groupby('pb_id')
              .first()
              .reset_index())
    
    return result

# %%
def has_complete_deals(deals):
        expected_range = range(1, max(deals) + 1)
        return set(deals) == set(expected_range)

def remove_incomplete_firms(df: pd.DataFrame) -> pd.DataFrame:
    complete_firms = df.groupby('pb_id')['deal_number'].agg(has_complete_deals)
    return df[df['pb_id'].isin(complete_firms[complete_firms].index)]

# remove firms with missing deals
# remove Accellerator deals (optionally add an indicator var to the firm)
# remove firms with deals that have missing values
# subset to early stage deals

def add_post_accelerator(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    
    # Find accelerator deals for each firm
    accelerator_dates = df[
        (df['deal_type'] == 'Accelerator/Incubator')
    ].groupby('pb_id')['deal_date'].min()
    
    # Mark deals that came after accelerator
    df['post_accelerator'] = False
    for pb_id, acc_date in accelerator_dates.items():
        df.loc[
            (df['pb_id'] == pb_id) & 
            (df['deal_date'] > acc_date), 
            'post_accelerator'
        ] = True
    
    return df

accelerator_ind_df = add_post_accelerator(df)

# %%
print(f"len(df)={len(df)}")

print(f"len(accelerator_ind_df)={len(accelerator_ind_df)}")
complete_firms_df = remove_incomplete_firms(accelerator_ind_df)

print(f"len(complete_firms_df)={len(complete_firms_df)}")
non_accellerator_deals_df = accelerator_ind_df[~accelerator_ind_df['deal_id'].isin(
    accelerator_ind_df[accelerator_ind_df.deal_type == 'Accelerator/Incubator']['deal_id']
)]

print(f"len(non_accellerator_deals_df)={len(non_accellerator_deals_df)}")
firms_with_known_deal_sizes_df = non_accellerator_deals_df[non_accellerator_deals_df['deal_size'].notna()]

print(f"len(firms_with_known_deal_sizes_df)={len(firms_with_known_deal_sizes_df)}")
# Out:
# len(df)=76546
# len(accelerator_ind_df)=76546
# len(complete_firms_df)=35218
# len(non_accellerator_deals_df)=69191
# len(firms_with_known_deal_sizes_df)=64321

# %%
early_stage_deals = get_early_stage_deals(firms_with_known_deal_sizes_df, 10)
print(f"len(early_stage_deals)={len(early_stage_deals)}")
early_stage_deals
# Out:
# len(early_stage_deals)=15917
#            pb_id     deal_id  \
# 0      100022-14  175697-20T
# 1      100024-12   86665-96T
# 2      100099-09   70049-98T
# 3      100100-26   95647-24T
# 4      100117-36   69514-66T
# ...          ...         ...
# 15912   99939-25   39874-33T
# 15913   99943-21   62715-97T
# 15914   99995-68   75683-35T
# 15915   99995-95   95638-24T
# 15916   99996-40  109587-43T
#
#                                                     name  deal_number  \
# 0                                           Spinn Coffee            6
# 1                                                  Maven            2
# 2                                             Weaveworks            2
# 3      Wonder (Artificial Intelligence & Machine Lear...            2
# 4                                   Shape Memory Medical            6
# ...                                                  ...          ...
# 15912                                            KnuEdge            1
# 15913                               Still Austin Whiskey            2
# 15914                                  Austin Eastciders            4
# 15915                                         AlertMedia            4
# 15916                   Key (Information Services (B2C))            2
#
#        year_founded  deal_date  deal_size post_valuation_status  \
# 0              2014 2022-01-10      34.74                Actual
# 1              2014 2017-11-20      11.00                Actual
# 2              2014 2016-05-11      15.00                Actual
# 3              2012 2017-06-30      12.60                Actual
# 4              2009 2017-07-19      14.00                Actual
# ...             ...        ...        ...                   ...
# 15912          2005 2005-01-28      12.00                   NaN
# 15913          2014 2018-12-18      15.40                Actual
# 15914          2013 2017-10-12      10.42                Actual
# 15915          2013 2017-10-11       8.57                Actual
# 15916          2014 2019-07-10       6.10                Actual
#
#        post_valuation  total_vc_funding  ...           company_website  \
# 0              133.74             44.47  ...             www.spinn.com
# 1               36.18             15.47  ...       www.mavenclinic.com
# 2               70.00             20.00  ...           www.weave.works
# 3               82.00             14.60  ...         www.askwonder.com
# 4               36.00             15.62  ...          www.shapemem.com
# ...               ...               ...  ...                       ...
# 15912             NaN             12.00  ...           www.knuedge.com
# 15913           36.40             16.48  ...       www.stillaustin.com
# 15914           29.42             16.75  ...  www.austineastciders.com
# 15915           42.87             17.58  ...        www.alertmedia.com
# 15916           12.10             13.69  ...                www.key.co
#
#              hq_location                                        description  \
# 0      San Francisco, CA  Developer of internet-connected coffee machine...
# 1           New York, NY  Developer of a digital health platform designe...
# 2      San Francisco, CA  Developer of a software as a service-based sof...
# 3             Dallas, TX  Developer of a desk research platform designed...
# 4        Santa Clara, CA  Developer of a medical device designed to cate...
# ...                  ...                                                ...
# 15912      San Diego, CA  Developer of next-generation voice biometric t...
# 15913         Austin, TX  Producer of a craft whiskey distillery intende...
# 15914         Austin, TX  Producer of traditionally crafted ciders inten...
# 15915         Austin, TX  Developer of a cloud-based emergency mass comm...
# 15916         Austin, TX  Developer of a travel management application d...
#
#                    primary_industry_code           primary_industry_group  \
# 0                   Household Appliances                Consumer Durables
# 1            Clinics/Outpatient Services              Healthcare Services
# 2      Software Development Applications                         Software
# 3         Business/Productivity Software                         Software
# 4                    Therapeutic Devices  Healthcare Devices and Supplies
# ...                                  ...                              ...
# 15912     Business/Productivity Software                         Software
# 15913                          Beverages            Consumer Non-Durables
# 15914                          Beverages            Consumer Non-Durables
# 15915             Communication Software                         Software
# 15916         Information Services (B2C)                            Media
#
#                     primary_industry_sector  \
# 0      Consumer Products and Services (B2C)
# 1                                Healthcare
# 2                    Information Technology
# 3                    Information Technology
# 4                                Healthcare
# ...                                     ...
# 15912                Information Technology
# 15913  Consumer Products and Services (B2C)
# 15914  Consumer Products and Services (B2C)
# 15915                Information Technology
# 15916  Consumer Products and Services (B2C)
#
#                                                 keywords  \
# 0      [automated coffee making, coffee maker, coffee...
# 1      [care coordination, care navigation, digital c...
# 2      [cloud computing saas, cloudtech and devops, c...
# 3      [business research services, content services,...
# 4      [cardiovascular, cardiovascular system, memory...
# ...                                                  ...
# 15912  [computational system, natural language techno...
# 15913  [alcohol wine, drinks cans, food cafe, gin dis...
# 15914  [cider company, cider maker, cider producer, c...
# 15915  [alerts monitoring, emergency communication, e...
# 15916  [concierge app, custom itineraries, personal c...
#
#                                                verticals post_accelerator  \
# 0                    [FoodTech, Internet of Things, TMT]             True
# 1                    [FemTech, HealthTech, Mobile, SaaS]            False
# 2                             [CloudTech & DevOps, SaaS]            False
# 3      [Artificial Intelligence & Machine Learning, S...            False
# 4                            [HealthTech, Life Sciences]             True
# ...                                                  ...              ...
# 15912  [Artificial Intelligence & Machine Learning, TMT]            False
# 15913                                                 []            False
# 15914                                       [E-Commerce]            False
# 15915                          [Climate Tech, SaaS, TMT]            False
# 15916                                              [TMT]            False
#
#       cumulative_funding
# 0                  44.02
# 1                  15.47
# 2                  20.00
# 3                  14.60
# 4                  15.62
# ...                  ...
# 15912              12.00
# 15913              16.48
# 15914              16.75
# 15915              17.58
# 15916              13.69
#
# [15917 rows x 28 columns]

# %%
from collections import Counter

def count_firms_per_tag(df: pd.DataFrame, tag_column: str) -> Counter:
    tag_counts = Counter()
    for pb_id, tags in df.groupby('pb_id')[tag_column].first().items():
        for tag in tags:
            tag_counts[tag] += 1
    return tag_counts

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder, MultiLabelBinarizer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold
import numpy as np
import pandas as pd
from typing import Dict, Tuple, Any
from scipy import stats

def prediction_interval(random_forest, X_pred, percentile=95):
    """Calculate prediction intervals using out-of-bag estimates"""
    predictions = []
    for estimator in random_forest.estimators_:
        predictions.append(estimator.predict(X_pred))
    predictions = np.array(predictions)
    lower = np.percentile(predictions, (100 - percentile) / 2, axis=0)
    upper = np.percentile(predictions, 100 - (100 - percentile) / 2, axis=0)
    return lower, upper

def predict_deal_size(df: pd.DataFrame, n_folds = 5) -> tuple:
    # Prepare categorical features
    le_location = LabelEncoder()
    le_industry = LabelEncoder()
    mlb_keywords = MultiLabelBinarizer()
    mlb_verticals = MultiLabelBinarizer()
    
    # Transform features
    X_location = le_location.fit_transform(df['hq_location']).reshape(-1, 1)
    X_industry = le_industry.fit_transform(df['primary_industry_code']).reshape(-1, 1)
    X_keywords = mlb_keywords.fit_transform(df['keywords'].tolist())
    X_verticals = mlb_verticals.fit_transform(df['verticals'].tolist())
    
    # Combine all features
    X = np.hstack([
        X_location,
        X_industry,
        X_keywords,
        X_verticals,
        df[['post_accelerator', 'cumulative_funding']].values
    ])
    
    y = df['deal_size'].values
    
    # Initialize model
    rf = RandomForestRegressor(n_estimators=10, random_state=42)
    
    # Perform k-fold cross-validation
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
    cv_scores = {
        'r2': cross_val_score(rf, X, y, cv=kf, scoring='r2'),
        'neg_rmse': cross_val_score(rf, X, y, cv=kf, scoring='neg_root_mean_squared_error'),
        'neg_mae': cross_val_score(rf, X, y, cv=kf, scoring='neg_mean_absolute_error')
    }

    # Train the model on all the data, now that we've cross-validated
    rf.fit(X, y)
    
    # Make predictions
    y_pred = rf.predict(X)
    residuals = y - y_pred

    # Calculate intervals for training data
    lower_bounds, upper_bounds = prediction_interval(rf, X)

    # Check distribution of residuals, hopefully random
    normality_test = stats.normaltest(residuals)
    
    # Get feature importance
    feature_names = (
        ['location', 'industry'] +
        mlb_keywords.classes_.tolist() +
        mlb_verticals.classes_.tolist() +
        ['post_accelerator', 'cumulative_funding']
    )
    
    importance_dict = dict(zip(feature_names, rf.feature_importances_))

    results = {
        'model': rf,
        'feature_importance': importance_dict,
        'cross_validation': {
            'r2_scores': cv_scores['r2'],
            'r2_mean': cv_scores['r2'].mean(),
            'r2_std': cv_scores['r2'].std(),
            'rmse_scores': -cv_scores['neg_rmse'],
            'rmse_mean': -cv_scores['neg_rmse'].mean(),
            'rmse_std': -cv_scores['neg_rmse'].std(),
            'mae_scores': -cv_scores['neg_mae'],
            'mae_mean': -cv_scores['neg_mae'].mean(),
            'mae_std': -cv_scores['neg_mae'].std()
        },
        'residual_analysis': {
            'residuals': residuals,
            'normality_test_statistic': normality_test.statistic,
            'normality_test_p_value': normality_test.pvalue
        },
        'prediction_intervals': {
            'lower_bounds': lower_bounds,
            'upper_bounds': upper_bounds
        },
        'encoders': {
            'location': le_location,
            'industry': le_industry,
            'keywords': mlb_keywords,
            'verticals': mlb_verticals
        }
    }
    
    return results

# %%
# %%time
results = predict_deal_size(early_stage_deals)
# Out:
# CPU times: user 41min 22s, sys: 39.9 s, total: 42min 2s
# Wall time: 50min 15s

# %%
results
# Out:
# {'model': RandomForestRegressor(n_estimators=10, random_state=42),
#  'feature_importance': {'location': np.float64(0.00046934169276340823),
#   'industry': np.float64(6.201047757834213e-08),
#   '1st party data': np.float64(0.0),
#   '3 d printing service': np.float64(0.0),
#   '3-d technology': np.float64(0.0),
#   '32 kwh lithium-ion battery': np.float64(2.0428386588521675e-08),
#   '340b management software': np.float64(5.4011425317225075e-08),
#   '340b software': np.float64(0.0),
#   '340b solutions': np.float64(0.0),
#   '360 cameras technology': np.float64(0.0),
#   '360 degree video': np.float64(0.0),
#   '360 imaging': np.float64(0.0),
#   '360 video': np.float64(5.946538420931858e-13),
#   '3d animation': np.float64(0.0),
#   '3d audio technology': np.float64(4.354984855177056e-08),
#   '3d avatar creation': np.float64(3.94659914663562e-10),
#   '3d bioprinting': np.float64(0.0),
#   '3d bioprinting technology': np.float64(0.0),
#   '3d capture': np.float64(0.0),
#   '3d capture systems': np.float64(0.0),
#   '3d capturing technologies': np.float64(3.9845753031272284e-07),
#   '3d cell culture': np.float64(0.0),
#   '3d character design': np.float64(0.0),
#   '3d computer vision': np.float64(9.767143994288724e-08),
#   '3d configurator': np.float64(0.0),
#   '3d construction': np.float64(0.0),
#   '3d construction model': np.float64(2.7178301064859674e-09),
#   '3d content': np.float64(7.348323284914236e-08),
#   '3d conversion technology': np.float64(1.3584720655753719e-10),
#   '3d data': np.float64(0.0),
#   '3d data sets': np.float64(7.103862610485887e-09),
#   '3d design collaboration': np.float64(2.5254277307809735e-07),
#   '3d design platform': np.float64(0.0),
#   '3d display technology': np.float64(0.0),
#   '3d filmmaking': np.float64(1.5504569606889962e-10),
#   '3d footwear': np.float64(0.0),
#   '3d games': np.float64(0.0),
#   '3d geospatial data': np.float64(0.0),
#   '3d glass': np.float64(0.0),
#   '3d graphics': np.float64(0.0),
#   '3d graphics and animation': np.float64(8.932776783415102e-08),
#   '3d holograms': np.float64(1.2616565172510772e-08),
#   '3d holograms application': np.float64(8.483405192833794e-08),
#   '3d holograms platform': np.float64(0.0),
#   '3d holographic display': np.float64(0.0),
#   '3d holographic imagers': np.float64(5.20037698681011e-10),
#   '3d home design': np.float64(0.0),
#   '3d imaging': np.float64(3.61488358221285e-07),
#   '3d imaging system': np.float64(0.0),
#   '3d imaging technology': np.float64(3.018812944075046e-12),
#   '3d imaging tool': np.float64(5.1955395491254876e-12),
#   '3d implants': np.float64(0.0),
#   '3d information': np.float64(0.0),
#   '3d interior design': np.float64(0.0),
#   '3d laser scanning': np.float64(2.3941046241831245e-10),
#   '3d lidar sensors': np.float64(0.0),
#   '3d machine vision': np.float64(0.0),
#   '3d mapping': np.float64(0.0),
#   '3d mapping services': np.float64(0.0),
#   '3d mapping system': np.float64(0.0),
#   '3d mapping technology': np.float64(4.696983575416582e-08),
#   '3d measurement': np.float64(0.0),
#   '3d media': np.float64(0.0),
#   '3d medical imaging': np.float64(1.1196855380233971e-07),
#   '3d metal': np.float64(0.0),
#   '3d metal printer': np.float64(0.0),
#   '3d metal printing': np.float64(0.0),
#   '3d model software': np.float64(0.0),
#   '3d modeling tools': np.float64(0.0),
#   '3d modelling software': np.float64(1.031247091565317e-07),
#   '3d module': np.float64(0.0),
#   '3d non-linear acoustic standing waves': np.float64(1.5539699460015078e-11),
#   '3d objects sensing': np.float64(1.0784163859706392e-07),
#   '3d perception product': np.float64(0.0),
#   '3d photography': np.float64(0.0),
#   '3d platform': np.float64(0.0),
#   '3d print metal parts': np.float64(0.0),
#   '3d print pharmaceutical': np.float64(0.0),
#   '3d printer': np.float64(5.510865453007288e-09),
#   '3d printer design': np.float64(0.0),
#   '3d printer developer': np.float64(0.0),
#   '3d printer technology': np.float64(1.8446840698565747e-11),
#   '3d printing': np.float64(3.0057946413987873e-07),
#   '3d printing business': np.float64(0.0),
#   '3d printing company': np.float64(0.0),
#   '3d printing composites parts': np.float64(2.681244510616647e-21),
#   '3d printing ecosystem': np.float64(0.0),
#   '3d printing firm': np.float64(0.0),
#   '3d printing hardware': np.float64(8.656724751794154e-08),
#   '3d printing machine': np.float64(0.0),
#   '3d printing manufacturing': np.float64(7.819180877240306e-11),
#   '3d printing materials': np.float64(3.305128765711943e-08),
#   '3d printing platform': np.float64(0.0),
#   '3d printing portal': np.float64(0.0),
#   '3d printing process': np.float64(1.0861895180966683e-07),
#   '3d printing robots': np.float64(7.103606671177893e-08),
#   '3d printing service': np.float64(1.206426842801817e-07),
#   '3d printing service provider': np.float64(0.0),
#   '3d printing software': np.float64(0.0),
#   '3d printing solutions': np.float64(0.0),
#   '3d printing system': np.float64(0.0),
#   '3d printing technology': np.float64(4.0749384607996174e-07),
#   '3d printing technology development': np.float64(2.7668104606170245e-09),
#   '3d printing tools': np.float64(0.0),
#   '3d project software': np.float64(0.0),
#   '3d scanning': np.float64(9.703371897219269e-09),
#   '3d scanning platform': np.float64(0.0),
#   '3d scanning systems': np.float64(0.0),
#   '3d sensing': np.float64(2.413900605596192e-07),
#   '3d sensing device': np.float64(1.8905808543834677e-08),
#   '3d sensing technology': np.float64(5.4796420881789526e-08),
#   '3d sensor': np.float64(2.138679784215093e-07),
#   '3d sensor technology': np.float64(3.320431325723746e-09),
#   '3d software': np.float64(0.0),
#   '3d spinal anatomy': np.float64(0.0),
#   '3d streaming technology': np.float64(1.6395183148579404e-09),
#   '3d technology': np.float64(7.233192838947722e-12),
#   '3d ultrasound system': np.float64(9.844277424599205e-10),
#   '3d user interface': np.float64(7.3892118030393764e-09),
#   '3d video conferencing': np.float64(0.0),
#   '3d virtual platform': np.float64(0.0),
#   '3d virtual reality': np.float64(0.0),
#   '3d vision': np.float64(0.0),
#   '3d vision software': np.float64(0.0),
#   '3d vision technology': np.float64(8.046851653519507e-10),
#   '3d visualization': np.float64(0.0),
#   '3d visualization software': np.float64(3.964254666767175e-09),
#   '3d visualization solution': np.float64(2.256239006414364e-07),
#   '3d visualization technology': np.float64(0.0),
#   '3d x-ray imaging': np.float64(0.0),
#   '401k earnings': np.float64(0.0),
#   '401k planning': np.float64(8.844178549000724e-10),
#   '401k savings': np.float64(0.0),
#   '4d imaging radar': np.float64(0.0),
#   '4d theatre': np.float64(0.0),
#   '4d ultrasound platform': np.float64(0.0),
#   '4g lte network': np.float64(5.6559243736915447e-08),
#   '4g network': np.float64(0.0),
#   '503b manufacturing facility': np.float64(2.3640043233845192e-08),
#   '5g': np.float64(1.3916299829067074e-07),
#   '5g and iot enabled devices': np.float64(0.0),
#   '5g communication technology': np.float64(0.0),
#   '5g connectivity': np.float64(1.015100706103372e-09),
#   '5g deployment': np.float64(0.0),
#   '5g infrastructure': np.float64(3.0119683731874705e-09),
#   '5g internet': np.float64(0.0),
#   '5g network': np.float64(8.192038758766312e-08),
#   '5g radio network': np.float64(0.0),
#   '5g solutions': np.float64(0.0),
#   '5g space': np.float64(0.0),
#   '5g spectrum': np.float64(4.204794488794698e-08),
#   '5g technology': np.float64(8.752314026767107e-09),
#   '5g wireless': np.float64(0.0),
#   '600 mw onshore wind park': np.float64(1.432208348095026e-08),
#   'a/b testing': np.float64(0.0),
#   'a/b testing platform': np.float64(1.2268960980491175e-08),
#   'a/b testing services': np.float64(0.0),
#   'a/b testing software': np.float64(8.897569590498093e-08),
#   'aav capsids synthesis': np.float64(0.0),
#   'aav gene therapy': np.float64(0.0),
#   'aav manufacturing': np.float64(5.869506363754442e-10),
#   'ab testing': np.float64(0.0),
#   'aba therapy': np.float64(1.6672717196618406e-07),
#   'abatement technology': np.float64(1.996436229493327e-11),
#   'abdominal aortic aneurysm': np.float64(6.790599420020121e-10),
#   'abdominal wall reconstruction': np.float64(0.0),
#   'abi custom application': np.float64(1.7784498491736876e-06),
#   'ablation catheter': np.float64(9.942376801726835e-09),
#   'ablation device': np.float64(0.0),
#   'ablation product': np.float64(0.0),
#   'ablation system': np.float64(8.229204783237093e-08),
#   'ablation therapy': np.float64(0.0),
#   'ablation treatment': np.float64(0.0),
#   'abm software': np.float64(0.0),
#   'abnormal uterine bleeding': np.float64(0.0),
#   'abnormality': np.float64(1.8266576577673776e-07),
#   'absence management': np.float64(2.1846324525472436e-07),
#   'absorbable biomaterials': np.float64(3.177713271630469e-08),
#   'absorbable implantables device': np.float64(4.457671062021628e-07),
#   'absorbable implants': np.float64(2.525192922600671e-07),
#   'absorbent process': np.float64(0.0),
#   'absorption technology': np.float64(0.0),
#   'abstract data forming': np.float64(4.202739709103123e-08),
#   'abstraction': np.float64(0.0),
#   'abuse deterrent technology': np.float64(0.0),
#   'academic assistance': np.float64(0.0),
#   'academic catalog management': np.float64(0.0),
#   'academic institution': np.float64(0.0),
#   'academic language': np.float64(1.5184496859189026e-08),
#   'academic medical center': np.float64(8.830956545472023e-08),
#   'academic operations platform': np.float64(3.685650437767278e-08),
#   'academic planning platform': np.float64(3.1534858613819277e-10),
#   'academic platform': np.float64(1.2728398419826004e-10),
#   'academic research': np.float64(0.0),
#   'academic research application': np.float64(2.071487242771273e-12),
#   'academic services': np.float64(0.0),
#   'academic support': np.float64(0.0),
#   'academic tutoring': np.float64(3.7888394039025604e-07),
#   'academic tutoring services': np.float64(0.0),
#   'academic vocabulary': np.float64(0.0),
#   'academy program': np.float64(4.032398502856159e-09),
#   'accelerate drug discovery': np.float64(0.0),
#   'accelerated computing': np.float64(0.0),
#   'accelerated development': np.float64(4.5836546085063447e-10),
#   'accelerated payment': np.float64(0.0),
#   'accelerating growth': np.float64(0.0),
#   'acceleration device': np.float64(9.066827990877036e-11),
#   'acceleration facility': np.float64(3.07073489002922e-08),
#   'acceleration platform': np.float64(0.0),
#   'acceleration program': np.float64(1.0185899130387231e-10),
#   'acceleration services': np.float64(2.585690844216504e-07),
#   'acceleration technology': np.float64(0.0),
#   'accelerator and incubator': np.float64(1.1944334197946378e-07),
#   'accelerator firm': np.float64(2.178022607482723e-08),
#   'accelerator funding': np.float64(0.0),
#   'accelerator platform': np.float64(1.3929012164568224e-07),
#   'accelerator program': np.float64(4.899667711222003e-07),
#   'accelerator programmes': np.float64(0.0),
#   'accelerator service': np.float64(6.340175132331715e-08),
#   'accelerator/incubator firm': np.float64(1.112358732813883e-07),
#   'access analytics tool': np.float64(0.0),
#   'access control': np.float64(2.619418882091297e-07),
#   'access control panel': np.float64(0.0),
#   'access control security': np.float64(0.0),
#   'access control software': np.float64(1.326054353957192e-08),
#   'access control system': np.float64(6.588677662547165e-08),
#   'access control technology': np.float64(0.0),
#   'access governance': np.float64(1.1913835058425825e-08),
#   'access information': np.float64(0.0),
#   'access management': np.float64(2.0365474197320416e-07),
#   'access management platform': np.float64(1.6797393872532802e-09),
#   'access management software': np.float64(0.0),
#   'access management system': np.float64(3.455144371730627e-09),
#   'access network': np.float64(0.0),
#   'access network provider': np.float64(8.689877937353812e-09),
#   'access network support': np.float64(0.0),
#   'access network support service': np.float64(1.6167011182256785e-07),
#   'access platform': np.float64(0.0),
#   'access point': np.float64(0.0),
#   'access security': np.float64(0.0),
#   'access solutions': np.float64(0.0),
#   'accessibility as a service': np.float64(7.687163996042283e-08),
#   'accessibility services': np.float64(3.7672879370053323e-10),
#   'accessibility testing': np.float64(0.0),
#   'accessibility-as-a-service platform': np.float64(0.0),
#   'accessories': np.float64(2.1470149286686378e-07),
#   'accessories apparel': np.float64(0.0),
#   'accessories brand': np.float64(1.3452771029608723e-08),
#   'accessories branding': np.float64(0.0),
#   'accessories marketplace': np.float64(8.54102734955511e-08),
#   'accessories platform': np.float64(0.0),
#   'accessories sales': np.float64(4.910051718997718e-08),
#   'accessories seller': np.float64(0.0),
#   'accessories shopping': np.float64(0.0),
#   'accessory dwellings': np.float64(0.0),
#   'accident alerts application': np.float64(7.500525722999942e-10),
#   'accident coverage': np.float64(3.510177785172913e-08),
#   'accident insurance': np.float64(0.0),
#   'accident prevention system': np.float64(0.0),
#   'accident reporting': np.float64(2.65313135740293e-08),
#   'accidental bowel movements': np.float64(0.0),
#   'accidental payment failure': np.float64(0.0),
#   'accommodation arrangement services': np.float64(0.0),
#   'accommodation booking platform': np.float64(1.2770801475816334e-09),
#   'accommodation books': np.float64(1.6834596044840824e-08),
#   'accommodation books marketplace': np.float64(0.0),
#   'accommodation books software': np.float64(0.0),
#   'accommodation marketplace': np.float64(0.0),
#   'accommodation rental': np.float64(2.4595787597952697e-08),
#   'accommodation rooms': np.float64(3.3865416415046333e-07),
#   'accommodation service': np.float64(1.3705807416587662e-07),
#   'accommodations marketplace': np.float64(3.667407841583116e-08),
#   'account & order management': np.float64(3.451426579778684e-08),
#   'account analysis': np.float64(0.0),
#   'account and order management': np.float64(0.0),
#   'account based intelligence': np.float64(7.180880397487385e-09),
#   'account based marketing': np.float64(2.5125329111601535e-08),
#   'account based marketing platform': np.float64(0.0),
#   'account based marketing software': np.float64(0.0),
#   'account intelligence': np.float64(0.0),
#   'account keeping': np.float64(3.29946291237537e-10),
#   'account maintenance': np.float64(0.0),
#   'account management': np.float64(7.740634528131242e-09),
#   'account management platform': np.float64(3.728579715575977e-08),
#   'account management services': np.float64(3.7695472152388635e-09),
#   'account mapping': np.float64(0.0),
#   'account monitoring': np.float64(3.2676941895982638e-09),
#   'account receivables management': np.float64(0.0),
#   'account reconciliation': np.float64(3.1129043678316055e-11),
#   'account security': np.float64(5.863864557363315e-08),
#   'account switching service': np.float64(1.0670697601930679e-08),
#   'account takeover prevention': np.float64(0.0),
#   'account takeover protection': np.float64(3.443628805721029e-08),
#   'account transfer': np.float64(5.722346516658273e-08),
#   'account transfer service': np.float64(1.457216917447096e-08),
#   'account verification': np.float64(1.8255791807665535e-07),
#   'account-based advertising': np.float64(0.0),
#   'account-based measurement': np.float64(0.0),
#   'account-based sales': np.float64(2.7172633795658814e-08),
#   'accountability system': np.float64(0.0),
#   'accountable care organization': np.float64(2.3603725761304724e-09),
#   'accountancy tools': np.float64(0.0),
#   'accounting analysis': np.float64(1.1289151305069516e-09),
#   'accounting and finance': np.float64(0.0),
#   'accounting and tax': np.float64(0.0),
#   'accounting app': np.float64(4.822799534775991e-10),
#   'accounting application': np.float64(6.404368417415324e-10),
#   'accounting automation': np.float64(0.0),
#   'accounting automation software': np.float64(0.0),
#   'accounting consulting service': np.float64(0.0),
#   'accounting data': np.float64(1.2726070027781007e-09),
#   'accounting data management': np.float64(0.0),
#   'accounting firm': np.float64(5.099790833152037e-08),
#   'accounting firm management': np.float64(1.698090082019765e-10),
#   'accounting insights': np.float64(0.0),
#   'accounting integration': np.float64(8.363763584426287e-08),
#   'accounting integration software': np.float64(6.524073648624599e-09),
#   'accounting management software': np.float64(0.0),
#   'accounting needs': np.float64(0.0),
#   'accounting platform': np.float64(0.0),
#   'accounting platform developer': np.float64(3.893363067396004e-08),
#   'accounting practice management': np.float64(2.8254709219018547e-08),
#   'accounting process': np.float64(4.0408388251263626e-10),
#   'accounting service': np.float64(0.0),
#   'accounting service provider': np.float64(0.0),
#   'accounting services': np.float64(3.9601734603196376e-08),
#   'accounting software': np.float64(1.4600482611033853e-07),
#   'accounting software firm': np.float64(0.0),
#   'accounting software platform': np.float64(0.0),
#   'accounting software provider': np.float64(0.0),
#   'accounting software service': np.float64(0.0),
#   'accounting software tools': np.float64(1.1002489996286839e-09),
#   'accounting softwares': np.float64(0.0),
#   'accounting solution': np.float64(1.0254692275213964e-07),
#   'accounting standards': np.float64(5.754131470236458e-13),
#   'accounting system': np.float64(0.0),
#   'accounting tools': np.float64(0.0),
#   'accounts payable': np.float64(0.0),
#   'accounts payable application': np.float64(1.3297926662110698e-09),
#   'accounts payable automation': np.float64(0.0),
#   'accounts payable automation software': np.float64(0.0),
#   'accounts payable management': np.float64(2.4273148800409682e-08),
#   'accounts payable process': np.float64(0.0),
#   'accounts payable solution': np.float64(0.0),
#   'accounts payable solutions': np.float64(0.0),
#   'accounts payable system': np.float64(4.494768136717666e-08),
#   'accounts receivable': np.float64(1.632057138026146e-08),
#   'accounts receivable automation': np.float64(0.0),
#   'accounts receivable business': np.float64(0.0),
#   'accounts receivable platform': np.float64(0.0),
#   'accounts receivable process': np.float64(0.0),
#   'accounts receivable software': np.float64(0.0),
#   'accreditation assistance': np.float64(5.911369443100291e-12),
#   'accreditation consulting services': np.float64(2.460083343899239e-08),
#   'accreditation management': np.float64(0.0),
#   'accredited investors': np.float64(0.0),
#   'accredited learning': np.float64(5.4329915288738775e-08),
#   'accuracy analysis': np.float64(0.0),
#   'accurate information': np.float64(0.0),
#   'accurate sizing and shaping': np.float64(0.0),
#   'accurate tool development': np.float64(0.0),
#   'acetic acid': np.float64(0.0),
#   'ach payment': np.float64(8.269899512262714e-08),
#   'ach processing': np.float64(0.0),
#   'acid salt': np.float64(1.5986154490357623e-07),
#   'acid-based medicine': np.float64(4.2036733959254746e-08),
#   'acne clearance': np.float64(2.1803848182826455e-10),
#   'acne control': np.float64(8.490450409785118e-12),
#   'acne medication': np.float64(0.0),
#   'acne patch treatment': np.float64(0.0),
#   'acne product': np.float64(0.0),
#   'acne skincare': np.float64(0.0),
#   'acne therapeutics': np.float64(0.0),
#   'acne therapy': np.float64(0.0),
#   'acne treatment': np.float64(4.1573599874328927e-11),
#   'acne treatment device': np.float64(1.0429536908821072e-07),
#   'acne treatment products': np.float64(1.6875336845524428e-07),
#   'acne treatment services': np.float64(0.0),
#   'acoustic cell processing': np.float64(0.0),
#   'acoustic diagnostics': np.float64(2.6570406283617908e-08),
#   'acoustic echo': np.float64(0.0),
#   'acoustic filters': np.float64(0.0),
#   'acoustic pressure': np.float64(1.0433596111119522e-08),
#   'acoustic sensor': np.float64(0.0),
#   'acoustic technology': np.float64(0.0),
#   'acquire financial assets': np.float64(0.0),
#   'acquiring company': np.float64(0.0),
#   'acquisition advisory': np.float64(0.0),
#   'acquisition company': np.float64(1.6862053770021366e-07),
#   'acquisition finance': np.float64(1.2165477187405126e-08),
#   'acquisition financing': np.float64(1.458672327760342e-09),
#   'acquisition firm': np.float64(1.3835130441731906e-13),
#   'acquisition platform': np.float64(1.0523441662199669e-09),
#   'acquisition services': np.float64(0.0),
#   'acquisition strategy consulting': np.float64(0.0),
#   'acquisition structure': np.float64(1.7114835305552087e-07),
#   'acrylic molecules': np.float64(2.4462816621255336e-10),
#   'actigraphy technology': np.float64(0.0),
#   'action game development': np.float64(0.0),
#   'action games': np.float64(0.0),
#   'action recognition': np.float64(0.0),
#   'actionable analytics': np.float64(3.5336567469555955e-07),
#   'actionable data': np.float64(0.0),
#   'actionable insights': np.float64(2.173358076397428e-07),
#   'actionable intelligence': np.float64(1.0491373412307547e-08),
#   'actionable intelligence platform': np.float64(0.0),
#   'actionable strategy': np.float64(0.0),
#   'activated carbon': np.float64(0.0),
#   'active apparel': np.float64(2.0750153672429243e-09),
#   'active cooling': np.float64(7.179035337421414e-10),
#   'active directory protection': np.float64(0.0),
#   'active ingredients developer': np.float64(2.173005116110532e-07),
#   'active layer solar': np.float64(0.0),
#   'active learning': np.float64(0.0),
#   'active learning platform': np.float64(0.0),
#   'active pharmaceutical ingredients': np.float64(0.0),
#   'active pharmaceutical product': np.float64(0.0),
#   'active suspension': np.float64(0.0),
#   'active suspension systems': np.float64(0.0),
#   'active wear': np.float64(0.0),
#   'activewear branding': np.float64(0.0),
#   'activewear clothing': np.float64(6.212843166734474e-08),
#   'activity monitoring device': np.float64(0.0),
#   'activity monitoring solution': np.float64(3.1367665556594636e-08),
#   'activity providers': np.float64(0.0),
#   'activity sourcing': np.float64(3.837278250791882e-08),
#   'activity tracker': np.float64(0.0),
#   'activity tracker device': np.float64(1.0811948860542584e-07),
#   'activity tracking': np.float64(4.250189821560542e-09),
#   'actuarial analysis': np.float64(0.0),
#   'actuators capacitors': np.float64(2.2635331429724803e-13),
#   'actuators drivers system': np.float64(0.0),
#   'acute breathing disorder': np.float64(0.0),
#   'acute care': np.float64(1.5965453747537048e-10),
#   'acute coronary syndrome': np.float64(0.0),
#   'acute healthcare': np.float64(0.0),
#   'acute kidney injury': np.float64(0.0),
#   'acute migraine drug': np.float64(0.0),
#   'acute myeloid leukemia': np.float64(4.668066415927507e-08),
#   'acute myeloid leukemia treatment': np.float64(0.0),
#   'acute organs injury': np.float64(3.7653657282591546e-08),
#   'acute pain': np.float64(5.85764418013931e-08),
#   'acute pain therapy': np.float64(0.0),
#   'acute thrombotic occlusion': np.float64(1.9214234819439682e-08),
#   'ad agency': np.float64(0.0),
#   'ad buy': np.float64(0.0),
#   'ad campaign': np.float64(0.0),
#   'ad channel': np.float64(0.0),
#   'ad creation': np.float64(9.585952967433379e-09),
#   'ad exchange': np.float64(0.0),
#   'ad intelligence': np.float64(6.668216355477251e-10),
#   'ad management': np.float64(0.0),
#   'ad management software': np.float64(0.0),
#   'ad measurement': np.float64(0.0),
#   'ad monetization': np.float64(0.0),
#   'ad network': np.float64(9.977663970093006e-11),
#   'ad optimization': np.float64(1.717870163008701e-08),
#   'ad platform': np.float64(5.7235495784477696e-08),
#   'ad research': np.float64(0.0),
#   'ad revenue': np.float64(5.094270246048033e-12),
#   'ad sales': np.float64(0.0),
#   'ad search engine': np.float64(3.919486369659833e-10),
#   'ad serving': np.float64(0.0),
#   'ad slots': np.float64(0.0),
#   'ad targeting': np.float64(0.0),
#   'ad tech': np.float64(0.0),
#   'ad tech company': np.float64(0.0),
#   'ad tech innovation': np.float64(0.0),
#   'ad tech platform': np.float64(0.0),
#   'ad testing': np.float64(3.771381828713767e-09),
#   'adaptation service': np.float64(0.0),
#   'adaptive ai': np.float64(1.9351030149866626e-20),
#   'adaptive authentication': np.float64(3.164064845662595e-08),
#   'adaptive charging': np.float64(2.6768114686449527e-07),
#   'adaptive computing': np.float64(3.5963321690273935e-10),
#   'adaptive immune system': np.float64(0.0),
#   'adaptive information management': np.float64(0.0),
#   'adaptive intelligence software': np.float64(0.0),
#   'adaptive learning': np.float64(3.054908757975771e-08),
#   'adaptive learning application': np.float64(0.0),
#   'adaptive learning platform': np.float64(5.20182804523947e-09),
#   'adaptive learning technology': np.float64(3.121941969136349e-11),
#   'adaptive literacy platform': np.float64(0.0),
#   'adaptive reading platform': np.float64(6.967474824562678e-08),
#   'adaptive robots': np.float64(0.0),
#   'adaptive security': np.float64(0.0),
#   'adaptive systems': np.float64(0.0),
#   'adaptogenic herbs': np.float64(0.0),
#   'adaptogenic product': np.float64(0.0),
#   'adaptogens beverages': np.float64(0.0),
#   'adblock recovery': np.float64(0.0),
#   'adc': np.float64(4.58969378549168e-06),
#   'addiction care': np.float64(0.0),
#   'addiction healing treatment': np.float64(0.0),
#   'addiction medicine': np.float64(1.9723445924084975e-09),
#   'addiction recovery': np.float64(0.0),
#   'addiction recovery center': np.float64(3.581892312345293e-08),
#   'addiction recovery program': np.float64(0.0),
#   'addiction recovery treatment': np.float64(0.0),
#   'addiction therapy': np.float64(0.0),
#   'addiction treatment': np.float64(1.3412146180904458e-06),
#   'addiction treatment center': np.float64(0.0),
#   'addiction treatment clinic': np.float64(0.0),
#   'addiction treatment drugs': np.float64(3.2937406985057736e-08),
#   'addiction treatment firm': np.float64(0.0),
#   'addiction treatment network': np.float64(0.0),
#   'addiction treatment programs': np.float64(0.0),
#   'additive manufacturer': np.float64(0.0),
#   'additives manufacturing': np.float64(6.029012763006701e-08),
#   'additives manufacturing design': np.float64(0.0),
#   'additives manufacturing firm': np.float64(4.280665915973916e-10),
#   'additives manufacturing materials': np.float64(1.8835526796697086e-07),
#   'additives manufacturing platform': np.float64(0.0),
#   'additives manufacturing system': np.float64(0.0),
#   'additives manufacturing technology': np.float64(3.114341591635548e-09),
#   'additives metal': np.float64(0.0),
#   'additives research': np.float64(0.0),
#   'address database': np.float64(0.0),
#   'address validation': np.float64(0.0),
#   'address verification': np.float64(0.0),
#   'adeno associated virus': np.float64(0.0),
#   'adeno-associated virus': np.float64(2.439912024078423e-08),
#   'adeno-associated virus services': np.float64(0.0),
#   'adeno-associated virus therapy': np.float64(0.0),
#   'adenocarcinoma cancer': np.float64(0.0),
#   'adenosine': np.float64(0.0),
#   'adhd': np.float64(4.995107178854283e-10),
#   'adhd drugs': np.float64(0.0),
#   'adhd tools': np.float64(0.0),
#   'adhd treatment': np.float64(2.2477775452940667e-08),
#   'adherence management': np.float64(0.0),
#   'adherence monitoring': np.float64(0.0),
#   'adherence monitoring software': np.float64(1.4475736546854538e-07),
#   'adherence packaging': np.float64(0.0),
#   'adhesives gel': np.float64(0.0),
#   'adhesives industry': np.float64(1.0238552542861447e-09),
#   'adhf treatment device': np.float64(0.0),
#   'adhf treatment medical device': np.float64(0.0),
#   'adipose tissue': np.float64(6.972207550721022e-09),
#   'adjustable lenses': np.float64(0.0),
#   'adjustable rate mortgage': np.float64(0.0),
#   'adjustment of data': np.float64(0.0),
#   'adjuvanted vaccines': np.float64(2.02357791773285e-09),
#   'admin portal': np.float64(0.0),
#   'administration and claims': np.float64(1.7675658665568623e-07),
#   'administration platform': np.float64(6.704893125457331e-08),
#   'administration process': np.float64(0.0),
#   'administration software': np.float64(0.0),
#   'administration system': np.float64(0.0),
#   'administration tools': np.float64(3.724317215029713e-08),
#   'administrative assistance': np.float64(0.0),
#   'administrative care': np.float64(0.0),
#   'administrative healthcare solutions': np.float64(0.0),
#   'administrative processes': np.float64(0.0),
#   'administrative saas': np.float64(0.0),
#   'administrative services': np.float64(7.62661903875167e-09),
#   'administrative services outsourcing': np.float64(0.0),
#   'administrative software': np.float64(3.5681571479914767e-08),
#   'administrative tasks': np.float64(0.0),
#   'administrative tasks management': np.float64(0.0),
#   'administrative technology': np.float64(0.0),
#   'admission guidance': np.float64(0.0),
#   'admission process': np.float64(0.0),
#   'admissions software': np.float64(0.0),
#   'adobe campaign provider': np.float64(0.0),
#   'adolescent psychiatry': np.float64(0.0),
#   'adoption management': np.float64(0.0),
#   'adoption platform': np.float64(2.5060982258831234e-09),
#   'adoption services': np.float64(0.0),
#   'adoptive cell therapy': np.float64(6.208613644812484e-10),
#   'adrenal cancer': np.float64(0.0),
#   'adrenal disease': np.float64(0.0),
#   'ads solutions': np.float64(0.0),
#   'adsorption technology': np.float64(0.0),
#   'adult beverages': np.float64(5.328156056905123e-09),
#   'adult care': np.float64(0.0),
#   'adult fiction': np.float64(0.0),
#   'adult healthcare': np.float64(2.2479738820290782e-10),
#   'adult learning': np.float64(0.0),
#   'adult pharmaceutical': np.float64(0.0),
#   'adult stem cell': np.float64(2.73958533231559e-10),
#   'adult support': np.float64(0.0),
#   'adult-use cannabis': np.float64(0.0),
#   'advanced analytics': np.float64(9.367485082019398e-07),
#   'advanced analytics tool': np.float64(4.2839746611666007e-08),
#   'advanced battery': np.float64(1.1108117963906004e-07),
#   'advanced materials': np.float64(1.2837717448489196e-07),
#   'advanced materials company': np.float64(0.0),
#   'advanced materials technology': np.float64(0.0),
#   'advanced persistent threat': np.float64(1.5121371749218101e-07),
#   'advanced polymers maker': np.float64(0.0),
#   'advanced technologies': np.float64(0.0),
#   'advancements tracking': np.float64(0.0),
#   'advances air mobility': np.float64(3.088326902498241e-07),
#   'advances analytics': np.float64(1.7387156599984237e-07),
#   'advances automated systems': np.float64(1.2499737129454736e-07),
#   'advances automation systems': np.float64(5.9549212610649247e-08),
#   'advances cellular therapy': np.float64(0.0),
#   'advances ceramic': np.float64(1.9415138613728938e-08),
#   'advances commercial drones operations': np.float64(0.0),
#   'advances drivers assistance solutions': np.float64(0.0),
#   'advances drivers assistance system': np.float64(0.0),
#   'advances drug discovery': np.float64(4.047144350520661e-07),
#   'advances endoscopy': np.float64(9.812535160655722e-22),
#   'advances energy': np.float64(0.0),
#   'advances energy storage': np.float64(0.0),
#   'advances farming technology': np.float64(0.0),
#   'advances fission': np.float64(0.0),
#   'advances implants': np.float64(1.4303031938272037e-07),
#   'advances intelligence': np.float64(3.142830181932002e-08),
#   'advances machine learning': np.float64(0.0),
#   'advances malware protection': np.float64(0.0),
#   'advances manufacturing': np.float64(2.3444828123678815e-08),
#   'advances mapping services': np.float64(0.0),
#   'advances materials': np.float64(0.0),
#   'advances materials research': np.float64(2.528029839587284e-08),
#   'advances metal alloy': np.float64(0.0),
#   'advances meter': np.float64(0.0),
#   'advances nuclear fission': np.float64(7.273819968980916e-08),
#   'advances packaging': np.float64(0.0),
#   'advances process control': np.float64(6.743921646069266e-10),
#   'advances reactor technology': np.float64(1.2757359697107101e-07),
#   'advances recycling': np.float64(0.0),
#   'advances robotics': np.float64(0.0),
#   'advances security platform': np.float64(0.0),
#   'advances security solutions': np.float64(1.0151569146917335e-07),
#   'advances signal processing': np.float64(0.0),
#   'advances therapeutics': np.float64(0.0),
#   'advances threat detection': np.float64(0.0),
#   'advances vending': np.float64(1.1709626137729748e-08),
#   'adventure apparel': np.float64(1.800067818236812e-07),
#   'adventure bikes': np.float64(0.0),
#   'adventure discovery platform': np.float64(0.0),
#   'adventure gadgets': np.float64(1.909934547190524e-07),
#   'adventure games': np.float64(0.0),
#   'adventure gear': np.float64(0.0),
#   'adventure travel': np.float64(0.0),
#   'adventure travel company': np.float64(0.0),
#   'adverting platform': np.float64(0.0),
#   'advertise agency': np.float64(0.0),
#   'advertise firm': np.float64(0.0),
#   'advertisement': np.float64(0.0),
#   'advertisement distribution': np.float64(0.0),
#   'advertisement distribution platform': np.float64(0.0),
#   'advertisement effectiveness': np.float64(0.0),
#   'advertisement exchange': np.float64(1.6415662199722074e-07),
#   'advertisement inventory management': np.float64(0.0),
#   'advertisement media': np.float64(0.0),
#   'advertisement monetization app': np.float64(0.0),
#   'advertisement monetization firm': np.float64(0.0),
#   'advertisement monetization tools': np.float64(0.0),
#   'advertisement network': np.float64(1.0729416388171565e-07),
#   'advertisement optimization': np.float64(2.6532418796644764e-08),
#   'advertisement performance': np.float64(1.4667486523662045e-07),
#   'advertisement platform': np.float64(2.1909066000188576e-08),
#   'advertisement rewards': np.float64(5.514785830941393e-08),
#   'advertisement service': np.float64(0.0),
#   'advertisement serving': np.float64(1.5932988823930137e-07),
#   'advertisement site': np.float64(0.0),
#   'advertisement software': np.float64(0.0),
#   'advertisement tools': np.float64(0.0),
#   'advertisement trafficking': np.float64(1.398521977032328e-07),
#   'advertisers network': np.float64(0.0),
#   'advertisers platform': np.float64(0.0),
#   'advertising': np.float64(9.392204560725788e-08),
#   'advertising agency': np.float64(8.75260020471039e-08),
#   'advertising analysis': np.float64(1.3297926661321538e-11),
#   'advertising analysis platform': np.float64(0.0),
#   'advertising analytics': np.float64(0.0),
#   'advertising analytics platform': np.float64(0.0),
#   'advertising analytics services': np.float64(0.0),
#   'advertising and marketing': np.float64(0.0),
#   'advertising application': np.float64(0.0),
#   'advertising automation platform': np.float64(0.0),
#   'advertising automation tools': np.float64(5.2388214701002906e-08),
#   'advertising branding': np.float64(1.2469294917649152e-10),
#   'advertising business consulting': np.float64(1.9206290343586534e-08),
#   'advertising business management': np.float64(2.8559351061119456e-08),
#   'advertising campaigns planning': np.float64(8.984332771135195e-08),
#   'advertising channel': np.float64(1.048929713572963e-11),
#   'advertising company': np.float64(0.0),
#   'advertising data': np.float64(3.2374373875606496e-12),
#   'advertising data marketplace': np.float64(1.4126710326755007e-09),
#   'advertising display': np.float64(0.0),
#   'advertising exchange company': np.float64(0.0),
#   'advertising film': np.float64(0.0),
#   'advertising insights': np.float64(0.0),
#   'advertising intelligence': np.float64(0.0),
#   'advertising intelligence platform': np.float64(0.0),
#   'advertising management': np.float64(0.0),
#   'advertising management platform': np.float64(0.0),
#   'advertising management system': np.float64(8.032990492485961e-10),
#   'advertising marketplace': np.float64(1.620590616530265e-07),
#   'advertising measurement': np.float64(0.0),
#   'advertising measurement service': np.float64(2.1880408338116666e-10),
#   'advertising media': np.float64(1.613892104010984e-11),
#   'advertising media company': np.float64(0.0),
#   'advertising monetization': np.float64(6.659309492145823e-09),
#   'advertising network': np.float64(5.884428338110652e-09),
#   'advertising network services': np.float64(7.880926516425085e-08),
#   'advertising optimization': np.float64(0.0),
#   'advertising platform': np.float64(4.996163271083467e-07),
#   'advertising platform company': np.float64(7.260424146894974e-08),
#   'advertising platform developer': np.float64(2.8184107622070674e-07),
#   'advertising platform operator': np.float64(1.3604715157204144e-07),
#   'advertising product': np.float64(0.0),
#   'advertising retargeting': np.float64(0.0),
#   'advertising revenue': np.float64(1.5333697219379063e-07),
#   'advertising sales': np.float64(0.0),
#   'advertising serve platform': np.float64(0.0),
#   'advertising service': np.float64(4.4326422206703073e-10),
#   'advertising service firm': np.float64(0.0),
#   'advertising service provider': np.float64(0.0),
#   'advertising services': np.float64(3.31823690683317e-08),
#   'advertising services company': np.float64(0.0),
#   'advertising site': np.float64(0.0),
#   'advertising software': np.float64(1.4039058373205188e-07),
#   'advertising solution': np.float64(1.1280705539873848e-07),
#   'advertising strategy': np.float64(2.8623887795063663e-08),
#   'advertising system': np.float64(0.0),
#   'advertising target': np.float64(1.4973825246975612e-11),
#   'advertising targeting': np.float64(0.0),
#   'advertising targeting data': np.float64(0.0),
#   'advertising technology': np.float64(6.668763652255739e-11),
#   'advertising technology company': np.float64(1.1648225924533153e-08),
#   'advertising technology developer': np.float64(8.904084048346707e-09),
#   'advertising technology platform': np.float64(2.151515675997966e-08),
#   'advertising technology service': np.float64(2.3140517504120304e-08),
#   'advertising technology software': np.float64(0.0),
#   'advertising tool': np.float64(7.138944666919254e-09),
#   'advertising video': np.float64(0.0),
#   'advertising work': np.float64(2.729192463345118e-08),
#   'advice service': np.float64(0.0),
#   'advisor services': np.float64(0.0),
#   'advisortech': np.float64(1.9167381417938134e-07),
#   'advisory automation software': np.float64(0.0),
#   'advisory platform': np.float64(0.0),
#   'advisory platform developer': np.float64(0.0),
#   'advisory service': np.float64(0.0),
#   'advisory service platform': np.float64(6.539394288107776e-09),
#   'advisory services': np.float64(3.7655063106898124e-10),
#   'advisory services firm': np.float64(0.0),
#   'advisory tools provider': np.float64(1.3857866624677782e-09),
#   'advocacy engagement platform': np.float64(0.0),
#   'advocacy group': np.float64(0.0),
#   'advocacy marketing': np.float64(1.771610075846622e-07),
#   'advocacy service': np.float64(0.0),
#   'advocacy software': np.float64(8.402076801839758e-09),
#   'advocate management platform': np.float64(1.9757431618510298e-07),
#   'advocate marketing': np.float64(1.2644853086408823e-09),
#   'aerial analytics': np.float64(0.0),
#   'aerial application': np.float64(0.0),
#   'aerial camera system': np.float64(6.435065084904531e-09),
#   'aerial data': np.float64(0.0),
#   'aerial data access': np.float64(6.970592345854968e-10),
#   'aerial data capture': np.float64(1.2074270490071164e-07),
#   'aerial data extraction': np.float64(4.4908165645840765e-09),
#   'aerial firefighting': np.float64(1.4150750683443879e-09),
#   'aerial imagery data': np.float64(1.6197912267834633e-07),
#   'aerial imagery platform': np.float64(0.0),
#   'aerial images': np.float64(0.0),
#   'aerial imaging': np.float64(0.0),
#   'aerial imaging analysis': np.float64(4.447319931877799e-08),
#   'aerial imaging system': np.float64(0.0),
#   'aerial imaging technology': np.float64(0.0),
#   'aerial inspection': np.float64(0.0),
#   'aerial inspection system': np.float64(0.0),
#   'aerial intelligence company': np.float64(0.0),
#   'aerial intelligence platform': np.float64(0.0),
#   'aerial mapping': np.float64(0.0),
#   'aerial mobility': np.float64(0.0),
#   'aerial monitoring': np.float64(1.5724727139378155e-07),
#   'aerial robotic platform': np.float64(0.0),
#   'aerial robotics': np.float64(0.0),
#   'aerial security device': np.float64(1.9946889992700413e-11),
#   'aerial spray services': np.float64(0.0),
#   'aerial surveillance systems': np.float64(0.0),
#   'aerial survey': np.float64(0.0),
#   'aerial system developer': np.float64(0.0),
#   'aerial systems': np.float64(0.0),
#   'aerial transportation': np.float64(0.0),
#   'aerial vehicle technology': np.float64(2.56402094836778e-09),
#   'aerial video': np.float64(4.990498074361254e-09),
#   'aero engineering service': np.float64(0.0),
#   'aerodynamic control': np.float64(6.31065933670019e-08),
#   'aerodynamic design': np.float64(0.0),
#   'aerodynamic device': np.float64(4.307066321150732e-09),
#   'aerodynamic product': np.float64(0.0),
#   'aerodynamic technology': np.float64(0.0),
#   'aerodynamics system': np.float64(1.188700513946956e-07),
#   'aerogel product': np.float64(0.0),
#   'aeronautical engineering': np.float64(0.0),
#   'aeronautical research': np.float64(0.0),
#   'aeronautics engineering': np.float64(0.0),
#   'aeroplane fuel cell': np.float64(0.0),
#   'aeroponic equipment': np.float64(0.0),
#   'aeroponic farming': np.float64(0.0),
#   'aeroponic technology': np.float64(1.0406473289281332e-09),
#   'aeroponic urban farming': np.float64(0.0),
#   'aeroponics system': np.float64(0.0),
#   'aerosol drugs': np.float64(1.43860014568098e-07),
#   'aerosol technology': np.float64(0.0),
#   'aerosol therapy': np.float64(7.682938046662548e-11),
#   'aerospace': np.float64(0.0),
#   'aerospace & defense': np.float64(0.0),
#   'aerospace and defense': np.float64(7.494508073134055e-07),
#   'aerospace and defense firm': np.float64(0.0),
#   'aerospace business': np.float64(0.0),
#   'aerospace company': np.float64(0.0),
#   'aerospace components': np.float64(0.0),
#   'aerospace components manufacturer': np.float64(0.0),
#   'aerospace components manufacturing': np.float64(0.0),
#   'aerospace control': np.float64(0.0),
#   'aerospace control system': np.float64(1.683354813859009e-11),
#   'aerospace design': np.float64(4.2097057564114405e-10),
#   'aerospace development': np.float64(0.0),
#   'aerospace device': np.float64(0.0),
#   'aerospace engineering': np.float64(7.73017694773132e-08),
#   'aerospace equipment': np.float64(7.048811051306439e-10),
#   'aerospace fasteners': np.float64(0.0),
#   'aerospace industry': np.float64(0.0),
#   'aerospace management': np.float64(1.778127035546544e-07),
#   'aerospace manufacturing': np.float64(2.3108461405007032e-07),
#   'aerospace manufacturing product': np.float64(2.3483909162339072e-07),
#   'aerospace market': np.float64(0.0),
#   'aerospace model': np.float64(0.0),
#   'aerospace parts provider': np.float64(0.0),
#   'aerospace platform': np.float64(4.3982429709325335e-07),
#   'aerospace product': np.float64(2.3369168296050184e-08),
#   'aerospace project': np.float64(0.0),
#   'aerospace research': np.float64(0.0),
#   'aerospace robotics': np.float64(0.0),
#   'aerospace science': np.float64(0.0),
#   'aerospace sector': np.float64(0.0),
#   'aerospace services': np.float64(0.0),
#   'aerospace software': np.float64(0.0),
#   'aerospace software technology': np.float64(0.0),
#   'aerospace solutions': np.float64(1.145093168228064e-07),
#   'aerospace technology': np.float64(3.470342445032496e-07),
#   'aerospace weapons': np.float64(0.0),
#   'aerostat system': np.float64(0.0),
#   'aesthetic application': np.float64(1.6323642926918853e-10),
#   'aesthetic care': np.float64(0.0),
#   'aesthetic dermatology': np.float64(4.8785978664150617e-08),
#   'aesthetic device': np.float64(1.9007828849338065e-07),
#   'aesthetic medical devices': np.float64(0.0),
#   'aesthetic medical product': np.float64(0.0),
#   'aesthetic medicine': np.float64(1.0391056714965981e-09),
#   'aesthetic product': np.float64(5.195539549007354e-12),
#   'aesthetic skincare': np.float64(0.0),
#   'aesthetic surgery': np.float64(3.735487639471432e-08),
#   'aesthetic therapy': np.float64(4.259552950717405e-08),
#   'aesthetic treatment device': np.float64(1.8922434311004205e-09),
#   'aesthetic treatment technology': np.float64(0.0),
#   'aesthetics clinic': np.float64(0.0),
#   'aesthetics treatment therapy': np.float64(0.0),
#   'affiliate marketing': np.float64(4.8999530153303836e-08),
#   'affiliate marketing channel': np.float64(0.0),
#   'affiliate marketing software': np.float64(7.737315845981738e-09),
#   'affiliate software': np.float64(9.441575331785993e-08),
#   'affinity chromatography': np.float64(1.3873450161424162e-09),
#   'affinity purification technology': np.float64(0.0),
#   'affordable and accessible': np.float64(0.0),
#   'affordable credit': np.float64(9.124769426170176e-08),
#   'affordable financing': np.float64(1.6817837803253602e-07),
#   'affordable healthcare': np.float64(1.59144838351881e-07),
#   'affordable healthcare services': np.float64(0.0),
#   'affordable homes finder': np.float64(0.0),
#   'affordable housing': np.float64(3.3244816654626675e-12),
#   'affordable housing company': np.float64(1.6830533621957305e-08),
#   'affordable housing services': np.float64(0.0),
#   'affordable medication': np.float64(1.636950227223178e-09),
#   'affordable retail': np.float64(0.0),
#   'african americans': np.float64(0.0),
#   'after sale services': np.float64(0.0),
#   'after-sales-marketing': np.float64(0.0),
#   'aftermarket automotive parts': np.float64(0.0),
#   'aftermarket car parts': np.float64(0.0),
#   'aftersales support': np.float64(9.711760796840533e-09),
#   'ag biotech': np.float64(1.502501434552484e-06),
#   'agave cultivation': np.float64(0.0),
#   'age-related disease': np.float64(2.995612730898757e-08),
#   'age-related disease treatment': np.float64(0.0),
#   'age-related macular degeneration': np.float64(2.2320677245141727e-09),
#   'age/sun spots/melasma': np.float64(0.0),
#   'aged care technology': np.float64(1.3792747935330864e-07),
#   'aged whiskey': np.float64(0.0),
#   'ageing process drugs': np.float64(4.77587835567164e-10),
#   'ageing therapeutics': np.float64(0.0),
#   'agency management platform': np.float64(0.0),
#   'agency management software': np.float64(1.6793784308487569e-09),
#   'agency management system': np.float64(0.0),
#   'agency platform': np.float64(0.0),
#   'agent & broker tech': np.float64(0.0),
#   'agent and broker technology': np.float64(5.356430809332392e-09),
#   'agent finding app': np.float64(0.0),
#   'agent productivity': np.float64(0.0),
#   'agent-centric software': np.float64(0.0),
#   'aggregated feed': np.float64(0.0),
#   'aggregation services': np.float64(1.2261510162706494e-07),
#   'aggregation switch': np.float64(2.309128692070455e-13),
#   'aggregator marketplace': np.float64(2.263533140002107e-09),
#   'agile architecture': np.float64(2.1294883667569058e-08),
#   'agile operations': np.float64(0.0),
#   'agile platform': np.float64(7.931031698480296e-08),
#   'agile project': np.float64(0.0),
#   'agile research': np.float64(0.0),
#   'agile semiconductor': np.float64(0.0),
#   'agile service management': np.float64(1.6083624605710868e-08),
#   'agile software': np.float64(6.550044476564758e-08),
#   'agile testing': np.float64(0.0),
#   'aging biology': np.float64(0.0),
#   'aging care': np.float64(0.0),
#   'aging cure': np.float64(7.586911851857872e-09),
#   'aging disease': np.float64(3.488508921004053e-08),
#   'aging disease prevention': np.float64(0.0),
#   'aging disease treatment': np.float64(3.293580471255669e-08),
#   'aging drugs': np.float64(0.0),
#   'aging frailty': np.float64(0.0),
#   'aging medicine': np.float64(0.0),
#   'aging process': np.float64(0.0),
#   'aging process slowdown': np.float64(0.0),
#   'aging related disease': np.float64(0.0),
#   'aging reversal': np.float64(0.0),
#   'aging spot & sun spot removal treatment': np.float64(0.0),
#   'aging therapeutics': np.float64(5.511214697236288e-08),
#   'aging therapy': np.float64(0.0),
#   'aging treatment': np.float64(0.0),
#   'agnostic drug discovery': np.float64(0.0),
#   'agnostic software': np.float64(1.3223029617124017e-10),
#   'agri equipment leasing': np.float64(0.0),
#   'agri technologies': np.float64(0.0),
#   'agri-food biotechnology': np.float64(0.0),
#   'agribusiness company': np.float64(0.0),
#   'agribusiness firm': np.float64(0.0),
#   'agribusiness insurance': np.float64(0.0),
#   'agribusiness marketplace': np.float64(3.280889673254508e-08),
#   'agribusiness sector': np.float64(3.452478882305417e-12),
#   'agribusiness service': np.float64(0.0),
#   'agribusiness system': np.float64(0.0),
#   'agricultural analysis': np.float64(0.0),
#   'agricultural application': np.float64(1.4730576564362397e-10),
#   'agricultural biological product': np.float64(6.917581449580256e-10),
#   'agricultural biotech': np.float64(1.2768557995651468e-08),
#   'agricultural biotechnology': np.float64(3.222058628330562e-11),
#   'agricultural biotechnology company': np.float64(0.0),
#   'agricultural business': np.float64(0.0),
#   'agricultural chemical product': np.float64(0.0),
#   'agricultural chemicals': np.float64(7.960481673399489e-08),
#   'agricultural chemicals formulation': np.float64(1.3694375497014296e-08),
#   'agricultural chemicals product': np.float64(7.639251787148916e-09),
#   'agricultural company': np.float64(7.63875008196046e-08),
#   'agricultural data': np.float64(1.0710653989975426e-08),
#   'agricultural data platform': np.float64(0.0),
#   'agricultural ecosystem': np.float64(0.0),
#   'agricultural equipment': np.float64(0.0),
#   'agricultural farm product': np.float64(0.0),
#   'agricultural farming': np.float64(0.0),
#   'agricultural farming service': np.float64(0.0),
#   'agricultural feedstock': np.float64(2.7670261047593027e-11),
#   'agricultural financing': np.float64(2.0101137485819963e-07),
#   'agricultural firm': np.float64(0.0),
#   'agricultural genomics': np.float64(0.0),
#   'agricultural implement technology': np.float64(1.3309574862304543e-10),
#   'agricultural information': np.float64(0.0),
#   'agricultural lighting kits': np.float64(0.0),
#   'agricultural management': np.float64(0.0),
#   'agricultural methodology': np.float64(0.0),
#   'agricultural microbial': np.float64(1.88867272321767e-09),
#   'agricultural parts': np.float64(0.0),
#   'agricultural payment': np.float64(0.0),
#   'agricultural pest control': np.float64(0.0),
#   'agricultural platform': np.float64(0.0),
#   'agricultural produce': np.float64(0.0),
#   'agricultural product': np.float64(8.138877572481048e-08),
#   'agricultural product marketplace': np.float64(4.915686013604454e-10),
#   'agricultural product retailer': np.float64(0.0),
#   'agricultural product seller': np.float64(0.0),
#   'agricultural residues': np.float64(0.0),
#   'agricultural robotic technology': np.float64(0.0),
#   'agricultural robotics': np.float64(0.0),
#   'agricultural science': np.float64(0.0),
#   'agricultural sector': np.float64(0.0),
#   'agricultural services': np.float64(0.0),
#   'agricultural software': np.float64(0.0),
#   'agricultural supply chain': np.float64(0.0),
#   'agricultural systems': np.float64(6.790599420039421e-11),
#   'agricultural technology': np.float64(3.0701628300225477e-07),
#   'agricultural technology company': np.float64(0.0),
#   'agricultural tools': np.float64(3.5327832358322893e-07),
#   'agricultural uses': np.float64(0.0),
#   'agricultural waste': np.float64(3.5468216654588377e-09),
#   'agricultural waste management': np.float64(1.966977146792165e-11),
#   'agricultural waste upcycling': np.float64(0.0),
#   'agricultural yield improvement': np.float64(0.0),
#   'agriculture': np.float64(1.3556158746299752e-07),
#   'agriculture analysis': np.float64(0.0),
#   'agriculture analytics': np.float64(2.0714873293628074e-11),
#   'agriculture app': np.float64(0.0),
#   'agriculture application': np.float64(0.0),
#   ...},
#  'cross_validation': {'r2_scores': array([0.99438623, 0.8033079 , 0.97916564, 0.98987409, 0.99284464]),
#   'r2_mean': np.float64(0.9519157036419233),
#   'r2_std': np.float64(0.07449375890028835),
#   'rmse_scores': array([ 3.34134013, 28.35521601,  8.40799669,  5.18531087,  4.00471752]),
#   'rmse_mean': np.float64(9.858916243083877),
#   'rmse_std': np.float64(-9.410752371820397),
#   'mae_scores': array([2.52743122, 2.93115295, 2.78045555, 2.67949639, 2.56020798]),
#   'mae_mean': np.float64(2.695748816577389),
#   'mae_std': np.float64(-0.1480247348363777)},
#  'residual_analysis': {'residuals': array([-1.76000000e+00, -4.53000000e-01,  0.00000000e+00, ...,
#          -5.93000000e-01,  1.77635684e-15, -7.60000000e-01]),
#   'normality_test_statistic': np.float64(67361.4937036622),
#   'normality_test_p_value': np.float64(0.0)},
#  'prediction_intervals': {'lower_bounds': array([34.74   ,  7.39875, 15.     , ..., 10.42   ,  8.57   ,  6.1    ]),
#   'upper_bounds': array([42.875 , 15.4275, 15.    , ..., 14.0925,  8.57  , 11.99  ])},
#  'encoders': {'location': LabelEncoder(),
#   'industry': LabelEncoder(),
#   'keywords': MultiLabelBinarizer(),
#   'verticals': MultiLabelBinarizer()}}

# %%
[t.tree_.max_depth for t in results['model'].estimators_]
# Out:
# [103, 120, 82, 81, 102, 92, 96, 127, 89, 118]

# %%
importance_dict = results['feature_importance']
{k: importance_dict[k] for k in sorted(importance_dict.keys(), key=lambda k: -1 * importance_dict[k])[0:50]}
# Out:
# {'cumulative_funding': np.float64(0.9689046514710977),
#  'automated transportation': np.float64(0.02385573340452695),
#  'human capital management': np.float64(0.002139400842357034),
#  'location': np.float64(0.00046934169276340823),
#  'global trading': np.float64(0.00022547813351037228),
#  'space transportation technology': np.float64(0.00017920418600157574),
#  'gaming studio': np.float64(0.00017372013267444192),
#  'erp': np.float64(0.00014817361810537779),
#  'Artificial Intelligence & Machine Learning': np.float64(8.691809592440341e-05),
#  'online gaming': np.float64(8.164006029571288e-05),
#  'digital game developer': np.float64(7.83494290152556e-05),
#  'TMT': np.float64(6.075213195490382e-05),
#  'post_accelerator': np.float64(5.9888540907561776e-05),
#  'blockchain platform': np.float64(5.679485839598737e-05),
#  'Life Sciences': np.float64(5.151623506980355e-05),
#  'SaaS': np.float64(5.089144046080033e-05),
#  'global energy': np.float64(4.9225895710203474e-05),
#  'scm': np.float64(3.545319100359307e-05),
#  'Industrials': np.float64(3.346884512397752e-05),
#  'Big Data': np.float64(3.2818265638463926e-05),
#  'Mobile': np.float64(3.2173349042510944e-05),
#  'fleet management': np.float64(3.162479325487336e-05),
#  'HealthTech': np.float64(3.133845803601514e-05),
#  'autonomous drives': np.float64(2.8336220624409917e-05),
#  'FinTech': np.float64(2.660310204968834e-05),
#  'supply chain management': np.float64(2.5003217814720285e-05),
#  'Real Estate Technology': np.float64(2.2761739776062753e-05),
#  'E-Commerce': np.float64(2.240830030111935e-05),
#  'Climate Tech': np.float64(2.1195426717024044e-05),
#  'blockchain technology': np.float64(2.1144960509468043e-05),
#  'payment gateway': np.float64(2.057310967495708e-05),
#  'electric vehicle manufacturing': np.float64(2.0425615352853418e-05),
#  'onboarding and payment': np.float64(1.966479904261191e-05),
#  'Manufacturing': np.float64(1.9593796905545415e-05),
#  'Cybersecurity': np.float64(1.9227221226041423e-05),
#  'co-working space': np.float64(1.8824487100793784e-05),
#  'LOHAS & Wellness': np.float64(1.8340745121719084e-05),
#  'CleanTech': np.float64(1.81170887764068e-05),
#  'electric suv': np.float64(1.7680809698401257e-05),
#  'Restaurant Technology': np.float64(1.6497852615065425e-05),
#  'autonomous vehicle': np.float64(1.6057840961811678e-05),
#  'electric vehicle platform': np.float64(1.5777679025417926e-05),
#  'cryptocurrency payment': np.float64(1.5530222577715013e-05),
#  'Oncology': np.float64(1.529100868757203e-05),
#  'cryptocurrency tools': np.float64(1.50236049674831e-05),
#  'home loan finance': np.float64(1.4568468244160392e-05),
#  'ai drug discovery': np.float64(1.4466726105023022e-05),
#  'entertainment industry': np.float64(1.4224920252173961e-05),
#  'Marketing Tech': np.float64(1.3145749269313064e-05),
#  'enterprise resource planning': np.float64(1.3130306434479996e-05)}

# %%
len(early_stage_deals)
# Out:
# 16415
